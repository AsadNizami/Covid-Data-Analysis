# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 80)
pd.set_option('display.max_rows', 1000)

# %%
def get_dataframe(name):
    
    file_name = f'Output/{name}.csv'
    return pd.read_csv(file_name)

dataset = get_dataframe('State-District age group ratio')

# %%
def plot(districts):
    age_distribution = [f'{i}-{i+9}' for i in range(1, 80, 10)]
    age_distribution.append('80 or more')
    fig = plt.subplots(figsize=(12, 8))
    for district in districts:
        df = dataset[dataset['District'] == district]
        
        y_axis = list(float(df.iloc[0, index]) for index in range(2, 11))
        plt.scatter(age_distribution, y_axis, label=district)
        
    plt.xlabel('Age group')
    plt.ylabel('Ratio Male:Female')
    plt.ylim(0,15)
    plt.legend()
    plt.show()
        
# plot(['Udupi', 'Kasaragod', 'Kalaburagi', 'Kodagu', 'Chikkaballapura', 'Mysuru'])
plot(dataset[dataset['State']=='Bihar']['District'].unique()[:10])
